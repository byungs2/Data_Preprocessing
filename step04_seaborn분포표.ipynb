# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# 분포도 차트 그리기

# %% [markdown]
# tips라는 데이터를 기반으로 도출해 낼 수 있는 가치는?
# - 금연 식당화 했을 때 결과가 어떨지
# - 흡연자 지출 비용을 더 많이 유발 하기 위한 전략

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips);

# %%
sns.set(style='darkgrid')
sns.relplot(x = 'total_bill', y = 'tip', data = tips);

# %% [markdown]
# 흡연자 비흡연자 비교하기 : yes/no  범주형 데이터

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker');

# %% [markdown]
# 사이즈 컴럼 적용해보기, 색을 수치형 데이터인 size에도 적용해보기, 농도로 표현

# %%
sns.set(style = 'white')
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'size', style = 'smoker');

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'size', style = 'smoker', palette= 'Blues');

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'size', style = 'smoker', palette = 'Blues' , size = 'size');
